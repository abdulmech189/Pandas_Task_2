# %% [markdown]
# ###### Assessment

# %% [markdown]
# ###### I am going to provide two .csv files , you are supposed to work on them and have to provide solutions to the following problems

# %% [markdown]
# ###### import necessary libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ###### merge those two csv files (after getting as dataframes, get them as a single dataframe)

# %%
df1 = pd.read_csv('/content/college_1.csv')
df2 = pd.read_csv('/content/college_2.csv')

# %%
df1
# Out:
#               Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0        A.Dharani    82.0   20.0              24500           24500
# 1      V.JEEVITHA     82.0   20.0              21740           21740
# 2      HEMAVATHI.R   100.0  100.0              19680           19680
# 3      Mugunthan S   100.0   47.0              10610           10610
# 4      Sathammai.S   100.0    8.0               8980            8980
# ..             ...     ...    ...                ...             ...
# 79    KarthikeyanS    45.0    0.0                  0               0
# 80        BARATH.P    29.0    0.0                  0               0
# 81   N.Ajith kumar    82.0    0.0                  0               0
# 82    mohamed nabi     0.0    0.0                  0               0
# 83  yaser ahamed.A     0.0   27.0                  0               0
#
#                                 Department  Rising
# 0         Computer Science and Engineering       0
# ...

# %%
df2
# Out:
#                       Name  python  python_en  mysql  computational_thinking  \
# 0            ASHOK KUMAR K     100          0     31                       9
# 1                  Chandru       0         20      0                       0
# 2        Ganesh Ramkumar R      -1         55     24                       6
# 3          Bodipudi Harini      -1          0     35                      -1
# 4                VIINU V P      -1        100     24                      -1
# 5               Poojitha Y       0         78     35                       0
# 6   Gowtham Chandrasekaran      -1          0      0                       3
# 7                Gowtham R      -1         60      4                       6
# 8                 shifak N      58          0      0                       0
# 9                  Balaji       -1        100     20                       0
# 10                Rushitha      -1         15     62                       9
# ...

# %%
df = pd.concat([df1, df2], ignore_index = True)
df
# Out:
#               Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0        A.Dharani    82.0   20.0              24500           24500
# 1      V.JEEVITHA     82.0   20.0              21740           21740
# 2      HEMAVATHI.R   100.0  100.0              19680           19680
# 3      Mugunthan S   100.0   47.0              10610           10610
# 4      Sathammai.S   100.0    8.0               8980            8980
# ..             ...     ...    ...                ...             ...
# 114  praveen raj j    24.0    0.0               2380            2380
# 115     AMARNATH D    -1.0   12.0               1890            1890
# 116           bala    32.0    0.0               1720            1720
# 117           XY Z    -1.0   -1.0                  0               0
# 118      Hariharan    -1.0   -1.0                  0               0
#
#                                     Department  Rising  python_en  \
# 0             Computer Science and Engineering       0        NaN
# ...

# %% [markdown]
# ###### Take each csv file , split that csv file into multiple categories (example csv files are added in the repo)

# %% [markdown]
# ###### consider if the codekata score exceeds 15000 points(present week) then make a csv on those observations as Exceeded expectations.csv

# %% [markdown]
# ###### if  10000<codekata score<15000   (Reached_expectations.csv)

# %% [markdown]
# ###### if  7000<codekata score<10000   (Needs_Improvement.csv)

# %% [markdown]
# ###### if  codekate score < 7000        (Unsatisfactory.csv)

# %%
df_exceed_expect = df[df['CodeKata Score']>15000]
df_exceed_expect.to_csv('Exceeded expectations.csv', index = False)

# %%
df_reached_expect = df[(df['CodeKata Score']>10000) & (df['CodeKata Score']<15000)]
df_reached_expect.to_csv('Reached_expectations.csv', index = False)

# %%
df_needs_expect = df[(df['CodeKata Score']>7000) & (df['CodeKata Score']<10000)]
df_needs_expect.to_csv('Needs_Improvement.csv', index = False)

# %%
df_unsatisfy = df[df['CodeKata Score']<7000]
df_unsatisfy.to_csv('Unsatisfactory.csv', index = False)

# %% [markdown]
# ###### Average of previous week geekions vs this week geekions (i.e Previous Geekions vs CodeKata Score)

# %%
df[['Previous Geekions', 'CodeKata Score']].mean()
# Out:
# Previous Geekions    3842.352941
# CodeKata Score       4051.764706
# dtype: float64

# %% [markdown]
# ###### No of students participated

# %%
df[df['CodeKata Score'] != 0].count()[0]
# Out:
# 112

# %% [markdown]
# ###### #Average completion of python course or my_sql or python english or computational thinking

# %%
mean_all = df.mean()
df[(df['python'] > mean_all[0]) | (df['mysql'] > mean_all[1]) | (df['python_en'] > mean_all[5]) | (df['computational_thinking'] > mean_all[6])].reset_index(drop = True)
# Out:
# <ipython-input-13-ff2651f67113>:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   mean_all = df.mean()
#              Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0       A.Dharani    82.0   20.0              24500           24500
# 1     V.JEEVITHA     82.0   20.0              21740           21740
# 2     HEMAVATHI.R   100.0  100.0              19680           19680
# 3     Mugunthan S   100.0   47.0              10610           10610
# 4     Sathammai.S   100.0    8.0               8980            8980
# ..            ...     ...    ...                ...             ...
# 94      sridhar.s    -1.0    0.0               3860            4440
# 95  M.Karthikeyan    -1.0    4.0               4020            4020
# 96      Abishak s    -1.0   35.0               3220            3220
# ...

# %% [markdown]
# ###### rising star of the week (top 3 candidate who performed well in that particular week)

# %%
df.sort_values(by = 'Rising', ascending  = False).head(3)
# Out:
#                   Name  python  mysql  Previous Geekions  CodeKata Score  \
# 92            shifak N    58.0    0.0               5180            8320
# 102     Narasimhan Y L    -1.0    0.0               4800            6800
# 86   Ganesh Ramkumar R    -1.0   24.0               8790           10790
#
#                                  Department  Rising  python_en  \
# 92   Electronics and Electrical Engineering    3140        0.0
# 102        Computer Science and Engineering    2000       -1.0
# 86         Computer Science and Engineering    2000       55.0
#
#      computational_thinking
# 92                      0.0
# 102                     0.0
# 86                      6.0

# %% [markdown]
# ###### Shining stars of the week (top 3 candidates who has highest geekions)

# %%
df.sort_values(by = 'Previous Geekions', ascending  = False).head(3)
# Out:
#           Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0    A.Dharani    82.0   20.0              24500           24500
# 1  V.JEEVITHA     82.0   20.0              21740           21740
# 2  HEMAVATHI.R   100.0  100.0              19680           19680
#
#                          Department  Rising  python_en  computational_thinking
# 0  Computer Science and Engineering       0        NaN                     NaN
# 1  Computer Science and Engineering       0        NaN                     NaN
# 2  Computer Science and Engineering       0        NaN                     NaN

# %% [markdown]
# ###### Department wise codekata performence (pie chart)

# %%
dept_perf = df['CodeKata Score'].groupby(df['Department']).sum()
plt.pie(dept_perf, labels = dept_perf.index, autopct = '%.1f', shadow = True, radius = 1)
# Out:
# ([<matplotlib.patches.Wedge at 0x7fe869293a90>,
# ...
#  [Text(-0.5411937677359137, 0.9576582405868004, 'Computer Science and Engineering'),
#   Text(0.1794146978630061, -1.085269720479995, 'Electronics and Communication Engineering'),
#   Text(1.0331050799533028, -0.3777484530407501, 'Electronics and Electrical Engineering')],
#  [Text(-0.29519660058322555, 0.5223590403200729, '66.4'),
#   Text(0.09786256247073058, -0.5919653020799972, '22.5'),
#   Text(0.5635118617927106, -0.20604461074950006, '11.2')])

# %% [markdown]
# ###### Department wise toppers (horizantal bar graph or any visual representations of your choice)

# %%
y = df['CodeKata Score'].groupby(df['Department'])

# %%
toppers = y.nlargest(1)
print(toppers)
# Out:
# Department
# Computer Science and Engineering           0     24500
# Electronics and Communication Engineering  87    10040
# Electronics and Electrical Engineering     84    19400
# Name: CodeKata Score, dtype: int64

# %%
toppers_index = []
for i in range(len(toppers)):
  toppers_index.append(toppers.index[i][1])

# %%
df_toppers = df.loc[toppers_index, ['Name', 'Department', 'CodeKata Score']].reset_index(drop = True)
df_toppers
# Out:
#               Name                                 Department  CodeKata Score
# 0        A.Dharani           Computer Science and Engineering           24500
# 1  Bodipudi Harini  Electronics and Communication Engineering           10040
# 2    ASHOK KUMAR K     Electronics and Electrical Engineering           19400

# %%
for i in range(len(df_toppers)):
  plt.barh(df_toppers.loc[i, 'Name'], df_toppers.loc[i, 'CodeKata Score'], label = df_toppers.loc[i, 'Department'])
  plt.legend()
  plt.xlabel('Codekata score')
  plt.ylabel('Toppers (each department)')
